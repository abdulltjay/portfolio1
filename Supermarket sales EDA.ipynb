# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Abdullahi\Desktop\finance and health datasets\supermarket_sales.csv")

# %%
df
# Out:
#       invoice_id branch       city customer_type gender_customer  \
# 0    750-67-8428      A     Yangon        Member          Female
# 1    226-31-3081      C  Naypyitaw        Normal          Female
# 2    631-41-3108      A     Yangon        Normal            Male
# 3    123-19-1176      A     Yangon        Member            Male
# 4    373-73-7910      A     Yangon        Normal            Male
# ..           ...    ...        ...           ...             ...
# 995  233-67-5758      C  Naypyitaw        Normal            Male
# 996  303-96-2227      B   Mandalay        Normal          Female
# 997  727-02-1313      A     Yangon        Member            Male
# 998  347-56-2442      A     Yangon        Normal            Male
# 999  849-09-3807      A     Yangon        Member          Female
#
#                product_line  unit_cost  quantity  5pct_markup    revenue  \
# 0         Health and beauty      74.69         7      26.1415   548.9715
# ...

# %%
df.isnull()
# Out:
#      invoice_id  branch   city  customer_type  gender_customer  product_line  \
# 0         False   False  False          False            False         False
# 1         False   False  False          False            False         False
# 2         False   False  False          False            False         False
# 3         False   False  False          False            False         False
# 4         False   False  False          False            False         False
# ..          ...     ...    ...            ...              ...           ...
# 995       False   False  False          False            False         False
# 996       False   False  False          False            False         False
# 997       False   False  False          False            False         False
# 998       False   False  False          False            False         False
# 999       False   False  False          False            False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# invoice_id         0
# branch             0
# city               0
# customer_type      0
# gender_customer    0
# product_line       0
# unit_cost          0
# quantity           0
# 5pct_markup        0
# revenue            0
# date               0
# time               0
# payment_method     0
# cogs               0
# gm_pct             0
# gross_income       0
# rating             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice_id       1000 non-null   object
#  1   branch           1000 non-null   object
#  2   city             1000 non-null   object
#  3   customer_type    1000 non-null   object
#  4   gender_customer  1000 non-null   object
#  5   product_line     1000 non-null   object
#  6   unit_cost        1000 non-null   float64
#  7   quantity         1000 non-null   int64
#  8   5pct_markup      1000 non-null   float64
#  9   revenue          1000 non-null   float64
#  10  date             1000 non-null   object
#  11  time             1000 non-null   object
#  12  payment_method   1000 non-null   object
#  13  cogs             1000 non-null   float64
#  14  gm_pct           1000 non-null   float64
#  15  gross_income     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#          unit_cost     quantity  5pct_markup      revenue        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#              gm_pct  gross_income      rating
# count  1.000000e+03   1000.000000  1000.00000
# mean   4.761905e+00     15.379369     6.97270
# std    6.131498e-14     11.708825     1.71858
# min    4.761905e+00      0.508500     4.00000
# 25%    4.761905e+00      5.924875     5.50000
# 50%    4.761905e+00     12.088000     7.00000
# ...

# %%
#to seperate categorcal columns from numerical columns 
cat=[]
num=[]
for column in df.columns:
    if df[column].nunique()>10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['branch',
#  'city',
#  'customer_type',
#  'gender_customer',
#  'product_line',
#  'quantity',
#  'payment_method',
#  'gm_pct']

# %%
num
# Out:
# ['invoice_id',
#  'unit_cost',
#  '5pct_markup',
#  'revenue',
#  'date',
#  'time',
#  'cogs',
#  'gross_income',
#  'rating']

# %% [markdown]
# # Univariate analysis

# %%
#to find the aggregate sales among branches(categorical column)
#use a countplot
sns.countplot(x='branch', data=df)
# Out:
# <Axes: xlabel='branch', ylabel='count'>

# %%
#to show the numbers
df['branch'].value_counts()
# Out:
# branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
#to show the percentage numbers in a graph(pie chart)
df['branch'].value_counts().plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#to find the most popular payment method used by customers
#using a barplot
df['payment_method'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='payment_method'>

# %%
# countplot to find the most popular payment method used by customers
sns.countplot(x='payment_method', data=df)
# Out:
# <Axes: xlabel='payment_method', ylabel='count'>

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
#to find the distrib ution of customer ratings.(numerical columns)
sns.distplot(df['rating'])
# Out:
# C:\Users\Abdullahi\AppData\Local\Temp\ipykernel_1820\3509919814.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['rating'])
# C:\Users\Abdullahi\anaconda2024\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='rating', ylabel='Density'>

# %%
df['rating'].skew()
# Out:
# 0.00900964876573073

# %%
#to find the distribution of cost of goods sold(numerical column)
sns.distplot(df['cogs'])
# Out:
# C:\Users\Abdullahi\AppData\Local\Temp\ipykernel_1820\298115287.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cogs'])
# C:\Users\Abdullahi\anaconda2024\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
#to find the skewness of the data
df['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
#to find the distribution of cost of goods sold using a boxplot(numerical column)
sns.boxplot(df['cogs'])
# Out:
# <Axes: >

# %% [markdown]
# # bivariate and multivariate analysis

# %%
#1. does the cost of goods sold affect the ratings that the customers provide?(numerical)
cat
# Out:
# ['branch',
#  'city',
#  'customer_type',
#  'gender_customer',
#  'product_line',
#  'quantity',
#  'payment_method',
#  'gm_pct']

# %%
num
# Out:
# ['invoice_id',
#  'unit_cost',
#  '5pct_markup',
#  'revenue',
#  'date',
#  'time',
#  'cogs',
#  'gross_income',
#  'rating']

# %%
#use a scatter plot
sns.scatterplot(x=df['cogs'], y=df['rating'])
#the csatterplot below does not show any relationship bteween them
# Out:
# <Axes: xlabel='cogs', ylabel='rating'>

# %%
#does gross income affect the ratings that the customers provide?(numerical=numerical)
sns.scatterplot(x=df['gross_income'], y=df['rating'])
# Out:
# <Axes: xlabel='gross_income', ylabel='rating'>

# %%
#3. to find the most profitable branch as per gross income(numerical-categorical)
#we use a barplot to find it
sns.barplot(x=df['branch'], y=df['gross_income'])
# Out:
# <Axes: xlabel='branch', ylabel='gross_income'>

# %% [markdown]
# # multivariate analysis

# %%
sns.barplot(x=df['branch'], y=df['gross_income'], hue=df['city'])
# Out:
# <Axes: xlabel='branch', ylabel='gross_income'>

# %%
#4.is there any reltionship bteween gender and gross income?(numerical-categorical)
sns.boxplot(x=df['gender_customer'], y=df['gross_income'])
# Out:
# <Axes: xlabel='gender_customer', ylabel='gross_income'>

# %%
#to do a multivariate analysis of the above
sns.boxplot(x=df['gender_customer'], y=df['gross_income'], hue=df['customer_type'])
# Out:
# <Axes: xlabel='gender_customer', ylabel='gross_income'>

# %%
#to find the product line that generates the most income(numeical_categorical)
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'customer_type', 'gender_customer',
#        'product_line', 'unit_cost', 'quantity', '5pct_markup', 'revenue',
#        'date', 'time', 'payment_method', 'cogs', 'gm_pct', 'gross_income',
#        'rating'],
#       dtype='object')

# %%
sns.barplot(x=df['product_line'], y=df['gross_income'])
plt.xticks(rotation=60)
plt.show()

# %%
#to find the hughest unit price in the product line
sns.barplot(x=df['product_line'], y=df['unit_cost'])
plt.xticks(rotation=60)
plt.show()

# %%
#to find the different payment method used by customers city-wise
pd.crosstab(df['city'], df['payment_method'])
# Out:
# payment_method  Cash  Credit card  Ewallet
# city
# Mandalay         110          109      113
# Naypyitaw        124           98      106
# Yangon           110          104      126

# %%
#using a heatmap
sns.heatmap(pd.crosstab(df['city'], df['payment_method']))
# Out:
# <Axes: xlabel='payment_method', ylabel='city'>

# %%
#which product line is ourchased in the highest quantity(
(df.groupby('product_line').sum()['quantity']).plot(kind='bar')
# Out:
# <Axes: xlabel='product_line'>

# %%
#display daily sales by the day of the week
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'customer_type', 'gender_customer',
#        'product_line', 'unit_cost', 'quantity', '5pct_markup', 'revenue',
#        'date', 'time', 'payment_method', 'cogs', 'gm_pct', 'gross_income',
#        'rating'],
#       dtype='object')
